# %% [markdown]
# <a href="https://colab.research.google.com/github/nsigitsutanto/Images/blob/master/img_augment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from skimage import io 
from skimage.transform import rotate, AffineTransform, warp
import matplotlib.pyplot as plt
import random
from skimage import img_as_ubyte
import os
from skimage.util import random_noise

# %%
img= cv2.imread(r"/content/drive/MyDrive/Test Augment/NS/RML NS Milky Orange 2020.jpg")
img= cv2.cvtColor(img, cv2.COLOR_RGB2BGR)

# %%
plt.imshow(img)
plt.show()

# %%
height, width, dims= img.shape
print(height, width, dims)
# Out:
# 1041 890 3

# %%
gray= cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
print(gray.shape)
# Out:
# (1041, 890)

# %%
plt.subplot(121)
plt.imshow(img)
plt.title("Original Image")
plt.subplot(122)
plt.imshow(gray)
plt.title("Gray Image")
plt.show()

# %%
img= cv2.resize(img,(700,700))
img.shape
# Out:
# (700, 700, 3)

# %%
plt.subplot(131) 
plt.title("Original Image") 
plt.imshow(img)

hflipped_image= np.fliplr(img) #fliplr reverse the order of columns of pixels in matrix
plt.subplot(132) 
plt.title("Horizontally flipped")
plt.imshow(hflipped_image)

vflipped_image= np.flipud(img) #flipud reverse the order of rows of pixels in matrix
plt.subplot(133)
plt.title("Vertically flipped")
plt.imshow(vflipped_image)
plt.show()

# %%
r_image = rotate(img, angle=45) # angle value is positive for anticlockwise rotation 
r_image1 = rotate(img, angle=-45)

# %%
plt.subplot(131)
plt.imshow(img)
plt.title("Original Image")
plt.subplot(132)
plt.imshow(r_image)
plt.title("45 degree rotated image")
plt.subplot(133)
plt.imshow(r_image1)
plt.title("-45 degree rotated image")
plt.show()

# %%
transform = AffineTransform(translation=(-200,0))  # (-200,0) are x and y coordinate, change it see the effect
warp_image = warp(img,transform, mode="wrap") #mode parameter is optional
# mode= {'constant', 'edge', 'symmetric', 'reflect', 'wrap'}
#these are possible values of mode, you can try them and decide which one to use, default value for mode is constant
plt.subplot(1,2,1)
plt.title('original image')
plt.imshow(img)
plt.subplot(1,2,2)
plt.title('Wrap Shift')
plt.imshow(warp_image)

# %%
noisy_image= random_noise(img)

# %%
plt.subplot(1,2,1)
plt.title('original image')
plt.imshow(img)
plt.subplot(1,2,2)
plt.title('Image after adding noise')
plt.imshow(noisy_image)

# %%
blur_image= cv2.GaussianBlur(img, (11,11),0)

# %%
plt.subplot(1,2,1)
plt.title('original image')
plt.imshow(img)
plt.subplot(1,2,2)
plt.title('Blurry image')
plt.imshow(blur_image)

# %%
#Lets define functions for each operation
def anticlockwise_rotation(image):
    angle= random.randint(0,180)
    return rotate(image, angle)

def clockwise_rotation(image):
    angle= random.randint(0,180)
    return rotate(image, -angle)

def h_flip(image):
    return  np.fliplr(image)

def v_flip(image):
    return np.flipud(image)

def add_noise(image):
    return random_noise(image)

def blur_image(image):
    return cv2.GaussianBlur(img, (9,9),0)

#I would not recommend warp_shifting, because it distorts image, but can be used in many use case like 
#classifying blur and non-blur images
def warp_shift(image): 
    transform = AffineTransform(translation=(0,40))  #chose x,y values according to your convinience
    warp_image = warp(image, transform, mode="wrap")
    return warp_image

# %%
transformations = {'rotate anticlockwise': anticlockwise_rotation,
                      'rotate clockwise': clockwise_rotation,
                      'horizontal flip': h_flip, 
                      'vertical flip': v_flip,
                   'warp shift': warp_shift,
                   'adding noise': add_noise,
                   'blurring image':blur_image
                 }                #use dictionary to store names of functions 

images_path="/content/drive/MyDrive/Test Augment/NS" #path to original images
augmented_path="/content/drive/MyDrive/Test Augment/Augment Result" # path to store aumented images
images=[] # to store paths of images from folder

for im in os.listdir(images_path):  # read image name from folder and append its path into "images" array     
    images.append(os.path.join(images_path,im))

images_to_generate=1000  #you can change this value according to your requirement
i=1                        # variable to iterate till images_to_generate

while i<=images_to_generate:    
    image=random.choice(images)
    original_image = io.imread(image)
    transformed_image=None
#     print(i)
    n = 0       #variable to iterate till number of transformation to apply
    transformation_count = random.randint(1, len(transformations)) #choose random number of transformation to apply on the image
    
    while n <= transformation_count:
        key = random.choice(list(transformations)) #randomly choosing method to call
        transformed_image = transformations[key](original_image)
        n = n + 1
        
    new_image_path= "%s/augmented_image_%s.jpg" %(augmented_path, i)
    transformed_image = img_as_ubyte(transformed_image)  #Convert an image to unsigned byte format, with values in [0, 255].
    transformed_image=cv2.cvtColor(transformed_image, cv2.COLOR_BGR2RGB) #convert image to RGB before saving it
    cv2.imwrite(new_image_path, transformed_image) # save transformed image to path
    i =i+1
#to generate more images, put above 3 statement inside while n<... loop

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import auth
auth.authenticate_user()
project_id = 'testing-automl-307206'
# !gcloud config set project {project_id}
# !gsutil ls
# Out:
# Updated property [core/project].
# gs://milkyorange/

# %%
bucket_name = 'milkyorange'
# !gsutil -m cp -r "/content/drive/MyDrive/Test Augment/augmentresult" gs://{bucket_name}/
# Out:
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_2.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_1.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_4.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_5.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_3.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_7.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_8.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_9.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_6.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_10.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_11.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_12.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_13.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_14.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_15.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_16.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_17.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_18.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_19.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_20.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_21.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_22.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_23.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_25.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_24.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_26.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_28.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_27.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_30.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_29.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_31.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_32.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_33.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_34.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_35.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_36.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_38.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_37.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_39.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_40.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_42.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_41.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_43.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_44.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_45.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_46.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_47.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_48.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_49.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_50.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_51.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_52.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_53.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_54.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_55.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_56.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_57.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_58.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_59.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_61.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_60.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_62.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_63.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_64.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_65.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_66.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_67.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_68.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_69.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_70.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_71.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_72.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_73.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_74.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_75.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_76.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_77.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_78.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_79.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_80.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_81.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_82.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_83.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_84.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_85.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_86.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_87.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_88.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_89.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_90.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_91.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_92.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_93.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_94.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_95.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_96.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_97.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_98.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_99.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_100.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_101.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_102.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_103.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_105.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_104.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_106.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_107.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_108.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_109.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_110.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_111.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_112.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_113.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_114.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_115.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_116.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_117.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_118.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_119.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_120.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_121.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_122.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_123.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_124.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_125.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_126.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_127.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_128.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_129.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_130.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_131.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_132.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_133.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_134.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_135.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_136.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_137.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_138.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_139.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_140.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_141.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_143.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_142.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_144.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_145.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_146.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_147.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_148.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_149.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_150.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_151.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_152.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_154.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_153.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_157.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_155.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_156.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_158.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_159.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_160.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_161.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_162.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_163.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_164.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_165.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_166.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_167.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_168.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_169.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_170.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_171.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_173.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_172.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_175.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_174.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_176.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_177.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_178.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_179.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_180.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_181.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_184.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_182.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_183.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_185.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_186.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_187.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_188.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_189.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image_190.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/Test Augment/augmentresult/augmented_image